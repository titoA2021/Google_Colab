# %% [markdown]
# <a href="https://colab.research.google.com/github/titoA2021/Google_Colab/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Datos tabulares
# index--> posiciones
# Mostrar convocatoria******************
# Desigualdad en PIB (2000 - 2016)
# Como se puede trabajar con la desigualdad (investigar)
import pandas as pd
data = {'var1': [11,12,14,33,22]}
# df: data frame(marco de datos)
# estructura tabular. 1fila-0 2fila-1
df = pd.DataFrame(data)

df['var1']
# Retorna la suma de los elementos de la columna
df['var1'].sum()
df['var1'].cumsum()
# Out:
# 0    11
# 1    23
# 2    37
# 3    70
# 4    92
# Name: var1, dtype: int64

# %%
data = {'pib':[10,45,543,87,56,32,43,78,54]}
df = pd.DataFrame(data)
# utilizo [[]] --> para volverlo DataFrame
df[['pib']]/10
# Out:
#     pib
# 0   1.0
# 1   4.5
# 2  54.3
# 3   8.7
# 4   5.6
# 5   3.2
# 6   4.3
# 7   7.8
# 8   5.4

# %%
# Coeficiente de gini 2014 - 0.491
# desigualdad => propiedad de tierra y capital
  # -> concentración economica en ciertas ciudades
  # -> capacidad institucional
  # -> situación del mercado laboral (segmentación, informalidad, subempleo)
  # -> niveles de educación
  # -> heterogeneidad estructural del aparato productivo
  # -> brechas en remuneración (por sexo, raza y lugar de origen)
  # -> estructura impositiva (politicas tributarias regresivas, excesiva carga del impuesto al consumo)
  # -> efecto de la violencia, conflicto armado, desplazamiento forzado
  # -> acceso a bienes y servicios

# es importante la heterogeneidad de los datos

# se va a analizar la desigualdad del ingreso en colombia destacando las heterogeneidades 
# y las brechas de ingreso por departamento

# la desigualdad se evalua segun las condiciones heterogeneas del ambiente

# La dimensión espacial es el lugar a evaluar (urbano-rural, departamentos,regiones geograficas, etc)

# Entre mas alto sea el nivel de desigualdad espacial hay mayores restricciones al desarrollo,
# y crecimiento economico, dificultades en el sistema de salud, problemas de criminalidad y violencia
# aumenta los indices de corrupción

# Segun la hipotesis de la "U invertida" (kuznets), la desigualdad aumenta en periodos inciales de desarrollo y
# crecimiento al concentrarse los beneficios sobre un sector en especifico
# una vez se llegue al punto de maxima desigualdad esta se reduce y luego se estabiliza en un nivel aceptable
# esto se da por el "efecto derrame"
# Por eso los niveles elevados de desigualdad regional serían una situación transitoria del proceso de desarrollo

# Sin embargo ya no se usa la metodologia de kuznets

# Para la desigualdad se toma el ingreso per capita familiar (IPCF)

# Tipos de indicadores: (no todos los indicadores fijan los mismos criterios)
  # -> comparación de valores especificos dentro de la distribución
  # -> estadisticos de dispersión
  # -> asociados a la curva de lorenz
  # -> de entropia
  # -> basados en modelos de bienestar social
  # -> segregación, segmentación y estratificación espacial

# Propiedades basicas de los indicadores de desigualdad:
  # independecia a la escala: no importa la escala 
  # invarianza a las replicas
  # independencia frente a los cambios de posición (anonimidad)
  # principio de transferencias Dalton-Pigou y normalización en 0

# El indicador de Gini cumple con todas estas propiedades, sin embargo, no cumple con:
  #

# %%
# indicador
df['pib'].max() - df['pib'].min()
# No es muy buena por que no se analiza los valores intermedios

# Rango intercuartilico, el ancho de la desigualdad
# Pero no me dice mucho de la desigualdad
df['pib'].describe()
# Out:
# count      4.000000
# mean     171.250000
# std      249.824438
# min       10.000000
# 25%       36.250000
# 50%       66.000000
# 75%      201.000000
# max      543.000000
# Name: pib, dtype: float64

# %%
# Dispersión con la varianza
# Puede ser mas precisa por ser la diferencia de una medida de tendencia central con todos los puntos 
# La media es sensible a los valores atipicos por eso la varianza se puede ver alterada o sesgada
df['pib'].var()
# Out:
# 62412.25

# %%
# Acá miro las respuestas relativas y no absolutas
PIB_t = df[['pib']].sum()
df['%PIB en el total'] = (df[['pib']]/PIB_t)*100
df
# Out:
#    pib  %PIB en el total
# 0   10          1.054852
# 1   45          4.746835
# 2  543         57.278481
# 3   87          9.177215
# 4   56          5.907173
# 5   32          3.375527
# 6   43          4.535865
# 7   78          8.227848
# 8   54          5.696203

# %% [markdown]
# # Cantidades de producción:
# En la siguiente base de datos encontrará los costos marginales de producción de algunas empresas colombianas para las cuales se tiene su  función inversa de demanda tal que:
# $$ p = \theta - \beta q$$
#
#
#
# suponga que $\Theta = 130$ y $\beta = 0.5$.
#
#
# \begin{equation}
# IT = \theta q - \beta q^{2}
# \end{equation}
#
#
# Calcular las cantidades optimas de producción de estas las empresas de una base de datos , si se enfrentan a esta demanda,  cual será la tasa de crecimiento promedio de la producción si los costos se reducen en 1.5%
#
# Cual es el precio de mercado?

# %%
#Problema 1
# precio dado las cantidades del producto
# beta: sensibilidad de precios y 
# cantidades(teta)
# CM = IM optimización de primer orden
# primera derivada y segunda derivada

# Calcular las cantidades optimas de producción para esas empressas
import numpy as np
import pandas as pd
teta = 130
beta = 0.5
data = {'CM':[np.random.randint(11,33) for x in range(100) ]}
data = pd.DataFrame(data)
data['q*'] =  (teta - data[['CM']])/(2*beta)
data
# Out:
#     CM     q*
# 0   29  101.0
# 1   32   98.0
# 2   25  105.0
# 3   12  118.0
# 4   13  117.0
# ..  ..    ...
# 95  19  111.0
# 96  24  106.0
# 97  13  117.0
# 98  29  101.0
# 99  28  102.0
#
# [100 rows x 2 columns]

# %%
import numpy as np 
import pandas as pd
import random
import matplotlib.pyplot as plt
a = ['Disease', 'No disease']
b = ['Female', 'Male']
N = 100
var1 = [random.choice(a) for x in range(N)]
var2 = [random.choice(b) for x in range(N)]
var3 = [np.random.weibull(1,N)]
var4 = [np.random.randint(24,60) for x in range(N)]
df = pd.DataFrame({'var1':var1, 'var2':var2, 'var3':var3[0], 'var4':var4}, )
df.to_excel('database2.xlsx')

# %%
df = pd.read_excel('database2.xlsx')
df.head(11)
# Out:
#     Unnamed: 0        var1    var2      var3  var4
# 0            0     Disease    Male  0.283750    56
# 1            1     Disease    Male  1.870175    37
# 2            2     Disease  Female  1.036134    34
# 3            3     Disease    Male  0.293941    37
# 4            4     Disease  Female  0.422826    39
# 5            5     Disease  Female  1.256467    37
# 6            6     Disease    Male  0.685022    44
# 7            7  No disease    Male  0.954137    31
# 8            8  No disease  Female  0.085477    41
# 9            9     Disease  Female  0.817152    43
# 10          10  No disease  Female  0.007613    37

# %%
df['var3'].describe()
# Out:
# count    100.000000
# mean       0.926270
# std        0.959807
# min        0.006808
# 25%        0.288319
# 50%        0.637438
# 75%        1.222733
# max        4.918783
# Name: var3, dtype: float64

# %%
feq = df['var2'].value_counts()
feq.plot.bar()

# %%
feq2 = df['var1'].value_counts()
#Grafica de barras
feq2.plot(kind='barh')

# %%
feq = pd.DataFrame(feq).reset_index()
feq
# Out:
#    level_0   index  var2
# 0        0    Male    51
# 1        1  Female    49

# %%
import pandas as pd

data = [1,20,20,17,16,17,20,18]
notas = pd.DataFrame(data, columns = ['Score'])
notas['z'] =  (notas['Score'] - notas['Score'].mean()) / notas['Score'].std()
# z distribución estandar del score
#notas.describe()
notas['notas- mean'] = notas['Score'] - notas['Score'].mean()
notas
# Out:
#    Score         z  notas- mean
# 0      1 -2.396291      -15.125
# 1     20  0.613926        3.875
# 2     20  0.613926        3.875
# 3     17  0.138628        0.875
# 4     16 -0.019804       -0.125
# 5     17  0.138628        0.875
# 6     20  0.613926        3.875
# 7     18  0.297061        1.875

# %%
notas['notas- mean'].sum()
# Out:
# 0.0
